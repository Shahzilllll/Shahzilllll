# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="So1j0DMA1GuwLE6hrfJS")
project = rf.workspace("muhmmad-ahmed").project("chess-piece-detection-lyl8o-gkdar")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 99.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Chess-Piece-Detection-1 in yolov8:: 100%|██████████| 318/318 [00:00<00:00, 9637.83it/s]

# %%
# !pip install ultralytics

from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Chess-Piece-Detection-1/data.yaml",
    epochs=10,
)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.2 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
 from ultralytics import YOLO
from google.colab import files
import cv2
import matplotlib.pyplot as plt

# Load your trained model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Upload an image to test
uploaded = files.upload()

# Pick the uploaded image filename
img_path = list(uploaded.keys())[0]

# Run prediction
results = model.predict(img_path, conf=0.25, show=False)

# Show the result
res_img = results[0].plot()
plt.imshow(cv2.cvtColor(res_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-f0214cb3-0f03-4003-b7f5-daccb4c51dc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0214cb3-0f03-4003-b7f5-daccb4c51dc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Continue training from your previous best model
model = YOLO("/content/runs/detect/train/weights/best.pt")

model.train(
    data="/content/Chess-Piece-Detection-1/data.yaml",
    epochs=40,   # 40 more → total ~50
    imgsz=640
)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load your NEW trained model
model = YOLO("/content/runs/detect/train2/weights/best.pt")  # adjust train2 → train3 if needed

# Test it on your knight image again
results = model.predict("wooden-chess-knight-piece-on-a-gray-background-photo.jpg", conf=0.1)

# Show result
res_img = results[0].plot()
plt.imshow(cv2.cvtColor(res_img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# image 1/1 /content/wooden-chess-knight-piece-on-a-gray-background-photo.jpg: 448x640 1 Knight, 12.4ms
# Speed: 4.9ms preprocess, 12.4ms inference, 24.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
c
# Out:
#      <input type="file" id="files-4f125dad-dc59-4b35-92ff-339ed3c2ee07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f125dad-dc59-4b35-92ff-339ed3c2ee07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# upload new piece image
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# run prediction
results = model.predict(img_path, conf=0.25)

# show result
annotated = results[0].plot()
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-0cb1e367-580c-4ac0-a41d-f1a84fc5f05e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cb1e367-580c-4ac0-a41d-f1a84fc5f05e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# upload new piece image
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# run prediction
results = model.predict(img_path, conf=0.25)

# show result
annotated = results[0].plot()
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-d3f50b68-f6e6-4243-8dbc-371b89bfe20f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3f50b68-f6e6-4243-8dbc-371b89bfe20f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# upload new piece image
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# run prediction
results = model.predict(img_path, conf=0.25)

# show result
annotated = results[0].plot()
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-0c978478-3a8d-497e-9229-1016a7ce2646" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c978478-3a8d-497e-9229-1016a7ce2646">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# upload new piece image
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# run prediction
results = model.predict(img_path, conf=0.25)

# show result
annotated = results[0].plot()
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-07c3daab-a7fb-4c21-a6a7-620940cfbe2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07c3daab-a7fb-4c21-a6a7-620940cfbe2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
